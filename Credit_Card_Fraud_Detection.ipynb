# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
import xgboost
from xgboost import XGBClassifier

# %%
data = pd.read_csv(r'D:\Credit_card\creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(data.value_counts())
# Out:
# Time      V1          V2          V3         V4         V5         V6         V7          V8          V9         V10        V11        V12        V13        V14        V15        V16        V17        V18        V19        V20        V21         V22        V23        V24        V25        V26        V27        V28        Amount  Class
# 163152.0  -1.196037    1.585949    2.883976   3.378471   1.511706   3.717077   0.585362   -0.156001    0.122648   4.217934   1.385525  -0.709405  -0.256168  -1.564352   1.693218  -0.785210  -0.228008  -0.412833   0.234834   1.375790  -0.370294    0.524395  -0.355170  -0.869790  -0.133198   0.327804  -0.035702  -0.858197  7.56    0        18
# ...

# %%
data.isnull().sum().any()
# Out:
# False

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.describe().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    8 non-null      float64
#  1   V1      8 non-null      float64
#  2   V2      8 non-null      float64
#  3   V3      8 non-null      float64
#  4   V4      8 non-null      float64
#  5   V5      8 non-null      float64
#  6   V6      8 non-null      float64
#  7   V7      8 non-null      float64
#  8   V8      8 non-null      float64
#  9   V9      8 non-null      float64
#  10  V10     8 non-null      float64
#  11  V11     8 non-null      float64
#  12  V12     8 non-null      float64
#  13  V13     8 non-null      float64
#  14  V14     8 non-null      float64
#  15  V15     8 non-null      float64
#  16  V16     8 non-null      float64
#  17  V17     8 non-null      float64
#  18  V18     8 non-null      float64
#  19  V19     8 non-null      float64
# ...

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
legit_data = data[data['Class'] == 0]
fraud_data = data[data['Class'] == 1]

# %%
legit_data,fraud_data
# Out:
# (            Time         V1         V2        V3        V4        V5  \
#  0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
#  1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
#  2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
#  3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
#  4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
#  ...          ...        ...        ...       ...       ...       ...
#  284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
#  284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
#  284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
#  284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
#  284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#                V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
print(legit_data.shape)
print(fraud_data.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit_data['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud_data['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample = legit_data.sample(n=492)

# %%
new_data = pd.concat([legit_sample,fraud_data],axis = 0)
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 164055  116416.0  1.923752 -1.312144 -0.590817 -0.903513 -1.086756 -0.294333
# 230238  146247.0  2.294948 -0.545851 -2.520212 -1.017679  0.203562 -1.488628
# 31028    36182.0 -1.409487  1.340579  0.936182 -0.074989  0.177147 -0.182929
# 212183  138754.0 -2.278007 -0.655742  1.046553 -2.232453 -0.938100 -0.704959
# 218603  141381.0  1.716372 -0.710430  1.092539  1.897359 -1.786604 -0.096220
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 164055 -0.892891 -0.011666 -0.194371  ...  0.053212 -0.108163  0.224331
# 230238  0.284533 -0.471086 -1.068005  ...  0.485400  1.412053 -0.254418
# 31028  -0.469360 -2.757012 -0.567552  ... -1.537977 -0.180683  0.392215
# 212183  1.225321  0.377405  0.281118  ...  0.076841 -0.669245  0.603958
# 218603 -1.233075  0.252286  1.967098  ...  0.261377  1.076448  0.236487
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94691.621951 -0.023446 -0.026656  0.121166 -0.031129 -0.068190
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.048897  0.063822 -0.000413 -0.021887  ... -0.009296  0.038278
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.041437  0.035010 -0.013152  0.009872 -0.001872  0.025070  0.003530
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       96.460813
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
x = new_data.iloc[:,:-1]
x.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 164055  116416.0  1.923752 -1.312144 -0.590817 -0.903513 -1.086756 -0.294333
# 230238  146247.0  2.294948 -0.545851 -2.520212 -1.017679  0.203562 -1.488628
# 31028    36182.0 -1.409487  1.340579  0.936182 -0.074989  0.177147 -0.182929
# 212183  138754.0 -2.278007 -0.655742  1.046553 -2.232453 -0.938100 -0.704959
# 218603  141381.0  1.716372 -0.710430  1.092539  1.897359 -1.786604 -0.096220
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 164055 -0.892891 -0.011666 -0.194371  ...  0.232572  0.053212 -0.108163
# 230238  0.284533 -0.471086 -1.068005  ... -0.169935  0.485400  1.412053
# 31028  -0.469360 -2.757012 -0.567552  ...  0.586257 -1.537977 -0.180683
# 212183  1.225321  0.377405  0.281118  ...  0.797998  0.076841 -0.669245
# 218603 -1.233075  0.252286  1.967098  ... -0.231079  0.261377  1.076448
#
# ...

# %%
y = new_data.iloc[:,-1]
y.head()
# Out:
# 164055    0
# 230238    0
# 31028     0
# 212183    0
# 218603    0
# Name: Class, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,stratify = y,random_state=4)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (688, 30)
# (296, 30)
# (688,)
# (296,)

# %%
logistic_regression = LogisticRegression()

# %%
logistic_regression.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
train_pred_1 = logistic_regression.predict(x_train)
test_pred_1 = logistic_regression.predict(x_test)

# %%
Accuracy = {}

# %%
log_reg_train_accuracy = accuracy_score(train_pred_1,y_train)
log_reg_test_accuracy = accuracy_score(test_pred_1,y_test)
print("Training accuracy is ",log_reg_train_accuracy)
print("Testing accuracy is ",log_reg_test_accuracy)
Accuracy['Logistic_regression accuracy'] = log_reg_test_accuracy
# Out:
# Training accuracy is  0.9534883720930233
# Testing accuracy is  0.9324324324324325

# %%
svm_model = SVC(kernel="linear")
svm_model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
train_pred_2 = svm_model.predict(x_train)
test_pred_2 = svm_model.predict(x_test)

# %%
svm_train_accuracy = accuracy_score(train_pred_2,y_train)
svm_test_accuracy = accuracy_score(test_pred_2,y_test)
print("Training accuracy is ",svm_train_accuracy)
print("Testing accuracy is ",svm_test_accuracy)
Accuracy['SVM accuracy'] = svm_test_accuracy
# Out:
# Training accuracy is  0.8982558139534884
# Testing accuracy is  0.9054054054054054

# %%
random_forest = RandomForestClassifier(n_estimators=10)
random_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
train_pred_3 = random_forest.predict(x_train)
test_pred_3 = random_forest.predict(x_test)

# %%
rand_forest_train_accuracy = accuracy_score(train_pred_3,y_train)
rand_forest_test_accuracy = accuracy_score(test_pred_3,y_test)
print("Training accuracy is ",rand_forest_train_accuracy)
print("Testing accuracy is ",rand_forest_test_accuracy)
Accuracy['Random_Forest accuracy'] = rand_forest_test_accuracy
# Out:
# Training accuracy is  0.9898255813953488
# Testing accuracy is  0.9459459459459459

# %%
bagging = BaggingClassifier(random_state = 100)
bagging.fit(x_train,y_train)
train_pred_4 = bagging.predict(x_train)
test_pred_4 = bagging.predict(x_test)
bagging_test_accuracy = accuracy_score(test_pred_4,y_test)
print("Testing accuracy is ",bagging_test_accuracy)
Accuracy['Bagging accuracy'] = bagging_test_accuracy
# Out:
# Testing accuracy is  0.9391891891891891

# %%
xgboost = XGBClassifier()
xgboost.fit(x_train,y_train)
test_pred_5 = xgboost.predict(x_test)
xgb_accuracy = accuracy_score(test_pred_5,y_test)
print("Testing accuracy is ",xgb_accuracy)
Accuracy['XGBoost accuracy'] = xgb_accuracy
# Out:
# Testing accuracy is  0.9425675675675675

# %%
Accuracy = pd.DataFrame([Accuracy]).T
Accuracy = Accuracy.rename(columns={0:'Accuracy_score'})
Accuracy
# Out:
#                               Accuracy_score
# Logistic_regression accuracy        0.932432
# SVM accuracy                        0.905405
# Random_Forest accuracy              0.945946
# Bagging accuracy                    0.939189
# XGBoost accuracy                    0.942568
